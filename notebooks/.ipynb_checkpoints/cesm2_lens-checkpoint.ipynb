# %% [markdown]
# # CESM2-LENS zarr data from NCAR's object store

# %%
# Imports
import intake
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import intake_esm
import glob
import pandas as pd
import os

# %%
import dask 
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.distributed import performance_report

# %%
# Set up your sratch folder path
username       = os.environ["USER"]
glade_scratch  = "/glade/derecho/scratch/" + username
print(glade_scratch)
# Out:
# /glade/derecho/scratch/harshah

# %%
gdex_data    = '/gdex/data/'
#
cesm_osdf_url  = 'https://osdata.gdex.ucar.edu/d010092/catalogs/d010092-osdf-zarr.json'
cesm_https_url = 'https://osdata.gdex.ucar.edu/d010092/catalogs/d010092-https-zarr.json'

# %% [markdown]
# ### Create PBS cluster and scale

# %%
# Create a PBS cluster object
cluster = PBSCluster(
    job_name = 'dask-wk24-hpc',
    cores = 1,
    memory = '4GiB',
    processes = 1,
    local_directory = glade_scratch+'/dask/',
    resource_spec = 'select=1:ncpus=1:mem=4GB',
    queue = 'casper',
    walltime = '5:00:00',
    log_directory = glade_scratch+'/dask/',
    #interface = 'ib0'
    interface = 'ext'
)
# Out:
# /glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35157 instead
#   warnings.warn(

# %%
cluster.scale(3)

# %%
cluster
# Out:
# PBSCluster(45327478, 'tcp://128.117.208.99:33481', workers=0, threads=0, memory=0 B)

# %% [markdown]
# ## Open catalogs

# %%
cat = intake.open_esm_datastore(cesm_https_url)
cat
# Out:
# <p><strong>gdex-cesm2-lens-zarr catalog with 40 dataset(s) from 322 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>322</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>313</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat.df
# Out:
#      Unnamed: 0 variable                                long_name component  \
# 0             0     FLNS             net longwave flux at surface       atm
# 1             1    FLNSC    clearsky net longwave flux at surface       atm
# 2             2     FLUT  upwelling longwave flux at top of model       atm
# 3             3     FSNS                net solar flux at surface       atm
# 4             4    FSNSC       clearsky net solar flux at surface       atm
# ..          ...      ...                                      ...       ...
# 317         317     WVEL                        vertical velocity       ocn
# 318         318      NaN                                      NaN       ocn
# 319         319      NaN                                      NaN       ocn
# 320         320      NaN                                      NaN       ocn
# 321         321      NaN                                      NaN       ocn
#
#      experiment forcing_variant frequency  vertical_levels spatial_domain  \
# 0    historical           cmip6     daily              1.0         global
# 1    historical           cmip6     daily              1.0         global
# 2    historical           cmip6     daily              1.0         global
# 3    historical           cmip6     daily              1.0         global
# 4    historical           cmip6     daily              1.0         global
# ..          ...             ...       ...              ...            ...
# 317      ssp370            smbb   monthly             60.0   global_ocean
# 318  historical            smbb    static              NaN   global_ocean
# 319  historical           cmip6    static              NaN   global_ocean
# 320      ssp370            smbb    static              NaN   global_ocean
# 321      ssp370           cmip6    static              NaN   global_ocean
#
#             units           start_time             end_time  \
# 0            W/m2  1850-01-01 12:00:00  2014-12-31 12:00:00
# 1            W/m2  1850-01-01 12:00:00  2014-12-31 12:00:00
# 2            W/m2  1850-01-01 12:00:00  2014-12-31 12:00:00
# 3            W/m2  1850-01-01 12:00:00  2014-12-31 12:00:00
# 4            W/m2  1850-01-01 12:00:00  2014-12-31 12:00:00
# ..            ...                  ...                  ...
# 317  centimeter/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 318           NaN                  NaN                  NaN
# 319           NaN                  NaN                  NaN
# 320           NaN                  NaN                  NaN
# 321           NaN                  NaN                  NaN
#
#                                                   path
# 0    https://stratus.gdex.ucar.edu/d010092/atm/dail...
# 1    https://stratus.gdex.ucar.edu/d010092/atm/dail...
# 2    https://stratus.gdex.ucar.edu/d010092/atm/dail...
# 3    https://stratus.gdex.ucar.edu/d010092/atm/dail...
# 4    https://stratus.gdex.ucar.edu/d010092/atm/dail...
# ..                                                 ...
# 317  https://stratus.gdex.ucar.edu/d010092/ocn/mont...
# 318  https://stratus.gdex.ucar.edu/d010092/ocn/stat...
# 319  https://stratus.gdex.ucar.edu/d010092/ocn/stat...
# 320  https://stratus.gdex.ucar.edu/d010092/ocn/stat...
# 321  https://stratus.gdex.ucar.edu/d010092/ocn/stat...
#
# [322 rows x 13 columns]

# %%
cat_temp = cat.search(variable='TREFHTMX',frequency='monthly')
cat_temp
# Out:
# <p><strong>gdex-cesm2-lens-zarr catalog with 4 dataset(s) from 4 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat_temp.df['path'].values
# Out:
# array(['https://stratus.gdex.ucar.edu/d010092/atm/monthly/cesm2LE-historical-cmip6-TREFHTMX.zarr',
#        'https://stratus.gdex.ucar.edu/d010092/atm/monthly/cesm2LE-historical-smbb-TREFHTMX.zarr',
#        'https://stratus.gdex.ucar.edu/d010092/atm/monthly/cesm2LE-ssp370-cmip6-TREFHTMX.zarr',
#        'https://stratus.gdex.ucar.edu/d010092/atm/monthly/cesm2LE-ssp370-smbb-TREFHTMX.zarr'],
#       dtype=object)

# %%
test = xr.open_zarr('https://osdata.gdex.ucar.edu/d010092/atm/monthly/cesm2LE-historical-cmip6-TREFHTMX.zarr')
test
# Out:
# <xarray.Dataset> Size: 22GB
# Dimensions:    (member_id: 50, time: 1980, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * member_id  (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#     time_bnds  (time, nbnd) object 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     TREFHTMX   (member_id, time, lat, lon) float32 22GB dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
# Attributes:
#     Conventions:       CF-1.0
#     NCO:               netCDF Operators version 4.9.4 (Homepage = http://nco....
#     logname:           sunseon
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     source:            CAM
#     time_period_freq:  month_1
#     topography_file:   /mnt/lustre/share/CESM/cesm_input/atm/cam/topo/fv_0.9x...

# %%
dsets = cat_temp.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.frequency.forcing_variant'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:03&lt;00:00]
#     </div>

# %%
dsets.keys()
# Out:
# dict_keys(['atm.historical.monthly.smbb', 'atm.ssp370.monthly.smbb', 'atm.ssp370.monthly.cmip6', 'atm.historical.monthly.cmip6'])

# %%
dset = dsets['atm.historical.monthly.smbb']
dset
# Out:
# <xarray.Dataset> Size: 22GB
# Dimensions:    (member_id: 50, time: 1980, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * member_id  (member_id) <U12 2kB 'r10i1191p1f2' ... 'r9i1171p1f2'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#     time_bnds  (time, nbnd) object 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     TREFHTMX   (member_id, time, lat, lon) float32 22GB dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
# Attributes: (12/22)
#     Conventions:                       CF-1.0
#     logname:                           sunseon
#     model_doi_url:                     https://doi.org/10.5065/D67H1H0V
#     source:                            CAM
#     time_period_freq:                  month_1
#     topography_file:                   /mnt/lustre/share/CESM/cesm_input/atm/...
#     ...                                ...
#     intake_esm_attrs:units:            K
#     intake_esm_attrs:start_time:       1850-01-16 12:00:00
#     intake_esm_attrs:end_time:         2014-12-16 12:00:00
#     intake_esm_attrs:path:             https://stratus.gdex.ucar.edu/d010092/...
#     intake_esm_attrs:_data_format_:    zarr
#     intake_esm_dataset_key:            atm.historical.monthly.smbb

# %%
# %%time
dset.TREFHTMX.isel(member_id=0,time=0).plot()
# Out:
# CPU times: user 378 ms, sys: 91.5 ms, total: 470 ms
# Wall time: 1.11 s

# %% [markdown]
# ### Using OSDF

# %%
cat_osdf = intake.open_esm_datastore(cesm_osdf_url)
cat_temp_osdf = cat_osdf.search(variable='TREFHTMX',frequency='monthly')
cat_temp_osdf
# Out:
# <p><strong>gdex-cesm2-lens-zarr catalog with 4 dataset(s) from 4 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat_temp_osdf.df['path'].values
# Out:
# array(['https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-historical-cmip6-TREFHTMX.zarr',
#        'https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-historical-smbb-TREFHTMX.zarr',
#        'https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-ssp370-cmip6-TREFHTMX.zarr',
#        'https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-ssp370-smbb-TREFHTMX.zarr'],
#       dtype=object)

# %%
test = xr.open_zarr('osdf:///ncar-gdex/d010092/atm/monthly/cesm2LE-historical-cmip6-TREFHTMX.zarr')
# Out:
# No working cache found
# ---------------------------------------------------------------------------
# NoAvailableSource                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 test = xr.open_zarr('osdf:///ncar-gdex/d010092/atm/monthly/cesm2LE-historical-cmip6-TREFHTMX.zarr')
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1535, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1521     raise TypeError(
#    1522         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1523     )
#    1525 backend_kwargs = {
#    1526     "synchronizer": synchronizer,
#    1527     "consolidated": consolidated,
#    (...)
#    1532     "zarr_format": zarr_format,
#    1533 }
# -> 1535 ds = open_dataset(
#    1536     filename_or_obj=store,
#    1537     group=group,
#    1538     decode_cf=decode_cf,
#    1539     mask_and_scale=mask_and_scale,
#    1540     decode_times=decode_times,
#    1541     concat_characters=concat_characters,
#    1542     decode_coords=decode_coords,
#    1543     engine="zarr",
#    1544     chunks=chunks,
#    1545     drop_variables=drop_variables,
#    1546     chunked_array_type=chunked_array_type,
#    1547     from_array_kwargs=from_array_kwargs,
#    1548     backend_kwargs=backend_kwargs,
#    1549     decode_timedelta=decode_timedelta,
#    1550     use_cftime=use_cftime,
#    1551     zarr_version=zarr_version,
#    1552     use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#    1553 )
#    1554 return ds
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1608, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1606 filename_or_obj = _normalize_path(filename_or_obj)
#    1607 if not store:
# -> 1608     store = ZarrStore.open_group(
#    1609         filename_or_obj,
#    1610         group=group,
#    1611         mode=mode,
#    1612         synchronizer=synchronizer,
#    1613         consolidated=consolidated,
#    1614         consolidate_on_close=False,
#    1615         chunk_store=chunk_store,
#    1616         storage_options=storage_options,
#    1617         zarr_version=zarr_version,
#    1618         use_zarr_fill_value_as_mask=None,
#    1619         zarr_format=zarr_format,
#    1620         cache_members=cache_members,
#    1621     )
#    1623 store_entrypoint = StoreBackendEntrypoint()
#    1624 with close_on_error(store):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:732, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     707 @classmethod
#     708 def open_group(
#     709     cls,
#    (...)
#     725     cache_members: bool = True,
#     726 ):
#     727     (
#     728         zarr_group,
#     729         consolidate_on_close,
#     730         close_store_on_close,
#     731         use_zarr_fill_value_as_mask,
# --> 732     ) = _get_open_params(
#     733         store=store,
#     734         mode=mode,
#     735         synchronizer=synchronizer,
#     736         group=group,
#     737         consolidated=consolidated,
#     738         consolidate_on_close=consolidate_on_close,
#     739         chunk_store=chunk_store,
#     740         storage_options=storage_options,
#     741         zarr_version=zarr_version,
#     742         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     743         zarr_format=zarr_format,
#     744     )
#     746     return cls(
#     747         zarr_group,
#     748         mode,
#    (...)
#     756         cache_members,
#     757     )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1811, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1808 elif consolidated is None:
#    1809     # same but with more error handling in case no consolidated metadata found
#    1810     try:
# -> 1811         zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1812     except (ValueError, KeyError):
#    1813         # ValueError in zarr-python 3.x, KeyError in 2.x.
#    1814         try:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/convenience.py:1360, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1357         metadata_key = "meta/root/consolidated/" + metadata_key
#    1359 # setup metadata store
# -> 1360 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1362 # pass through
#    1363 chunk_store = kwargs.pop("chunk_store", None) or store
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:3046, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3043 self.store = Store._ensure_store(store)
#    3045 # retrieve consolidated metadata
# -> 3046 meta = json_loads(self.store[metadata_key])
#    3048 # check format of consolidated metadata
#    3049 consolidated_format = meta.get("zarr_consolidated_format", None)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1444 key = self._normalize_key(key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#    1448     raise KeyError(key) from e
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     153 k = self._key_to_str(key)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions as exc:
#     157     if default is not None:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/venvs/osdf/lib/python3.10/site-packages/pelicanfs/core.py:764, in PelicanFileSystem._cache_multi_dec.<locals>.wrapper(self, *args, **kwargs)
#     762         data_url = await self.get_origin_url(path)
#     763     else:
# --> 764         data_url = await self.get_working_cache(path)
#     765 else:
#     766     data_url = []
#
# File ~/venvs/osdf/lib/python3.10/site-packages/pelicanfs/core.py:380, in PelicanFileSystem.get_working_cache(self, fileloc)
#     378 if not cache_list:
#     379     logger.error("No working cache found")
# --> 380     raise NoAvailableSource()
#     382 with self._namespace_lock:
#     383     self._namespace_cache[namespace] = _CacheManager(cache_list)
#
# NoAvailableSource:

# %%
dsets_osdf = cat_temp_osdf.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.frequency.forcing_variant'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions as exc:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:477, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     476     if ex:
# --> 477         raise ex
#     478 if (
#     479     len(paths) > 1
#     480     or isinstance(path, list)
#     481     or paths[0] != self._strip_protocol(path)
#     482 ):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:257, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     256 try:
# --> 257     return await asyncio.wait_for(coro, timeout=timeout), i
#     258 except Exception as e:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/asyncio/tasks.py:408, in wait_for(fut, timeout)
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:236, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     235     out = await r.read()
# --> 236     self._raise_not_found_for_status(r, url)
#     237 return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:218, in HTTPFileSystem._raise_not_found_for_status(self, response, url)
#     217 if response.status == 404:
# --> 218     raise FileNotFoundError(url)
#     219 response.raise_for_status()
#
# FileNotFoundError: https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-ssp370-smbb-TREFHTMX.zarr/.zmetadata
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/mapping.py:159, in FSMap.__getitem__(self, key, default)
#     158         return default
# --> 159     raise KeyError(key) from exc
#     160 return result
#
# KeyError: '.zmetadata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1811, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1810 try:
# -> 1811     zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1812 except (ValueError, KeyError):
#    1813     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/convenience.py:1360, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1359 # setup metadata store
# -> 1360 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1362 # pass through
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:3046, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3045 # retrieve consolidated metadata
# -> 3046 meta = json_loads(self.store[metadata_key])
#    3048 # check format of consolidated metadata
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1448, in FSStore.__getitem__(self, key)
#    1447 except self.exceptions as e:
# -> 1448     raise KeyError(key) from e
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1815, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1814 try:
# -> 1815     zarr_root_group = zarr.open_group(store, **open_kwargs)
#    1816     emit_user_level_warning(
#    1817         "Failed to open Zarr store with consolidated metadata, "
#    1818         "but successfully read with non-consolidated metadata. "
#    (...)
#    1828         RuntimeWarning,
#    1829     )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/source.py:256, in ESMDataSource._open_dataset(self)
#     235 datasets = [
#     236     _open_dataset(
#     237         record[self.path_column_name],
#    (...)
#     253     for _, record in self.df.iterrows()
#     254 ]
# --> 256 datasets = dask.compute(*datasets)
#     257 if len(datasets) == 1 or not datasets[0].data_vars:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/dask/base.py:656, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     655 with shorten_traceback():
# --> 656     results = schedule(dsk, keys, **kwargs)
#     658 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/source.py:82, in _open_dataset(urlpath, varname, xarray_open_kwargs, preprocess, requested_variables, additional_attrs, expand_dims, data_format, storage_options)
#      81 else:
# ---> 82     ds = xr.open_dataset(url, **xarray_open_kwargs)
#      83     if preprocess is not None:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1608, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1607 if not store:
# -> 1608     store = ZarrStore.open_group(
#    1609         filename_or_obj,
#    1610         group=group,
#    1611         mode=mode,
#    1612         synchronizer=synchronizer,
#    1613         consolidated=consolidated,
#    1614         consolidate_on_close=False,
#    1615         chunk_store=chunk_store,
#    1616         storage_options=storage_options,
#    1617         zarr_version=zarr_version,
#    1618         use_zarr_fill_value_as_mask=None,
#    1619         zarr_format=zarr_format,
#    1620         cache_members=cache_members,
#    1621     )
#    1623 store_entrypoint = StoreBackendEntrypoint()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:732, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     707 @classmethod
#     708 def open_group(
#     709     cls,
#    (...)
#     725     cache_members: bool = True,
#     726 ):
#     727     (
#     728         zarr_group,
#     729         consolidate_on_close,
#     730         close_store_on_close,
#     731         use_zarr_fill_value_as_mask,
# --> 732     ) = _get_open_params(
#     733         store=store,
#     734         mode=mode,
#     735         synchronizer=synchronizer,
#     736         group=group,
#     737         consolidated=consolidated,
#     738         consolidate_on_close=consolidate_on_close,
#     739         chunk_store=chunk_store,
#     740         storage_options=storage_options,
#     741         zarr_version=zarr_version,
#     742         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     743         zarr_format=zarr_format,
#     744     )
#     746     return cls(
#     747         zarr_group,
#     748         mode,
#    (...)
#     756         cache_members,
#     757     )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1831, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1830         except missing_exc as err:
# -> 1831             raise FileNotFoundError(
#    1832                 f"No such file or directory: '{store}'"
#    1833             ) from err
#    1835 # but the user should still receive a DataTree whose root is the group they asked for
#
# FileNotFoundError: No such file or directory: 'https://osdf-data.gdex.ucar.edu/ncar-gdex/d010092/atm/monthly/cesm2LE-ssp370-smbb-TREFHTMX.zarr'
#
# The above exception was the direct cause of the following exception:
#
# ESMDataSourceError                        Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 dsets_osdf = cat_temp_osdf.to_dataset_dict()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py:38, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      36 @functools.wraps(wrapped)
#      37 def wrapper_function(*args, **kwargs):
# ---> 38     return wrapper(*args, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/pydantic/_internal/_validate_call.py:111, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     110 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# --> 111     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     112     if self.__return_pydantic_validator__:
#     113         return self.__return_pydantic_validator__(res)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/core.py:689, in esm_datastore.to_dataset_dict(self, xarray_open_kwargs, xarray_combine_by_coords_kwargs, preprocess, storage_options, progressbar, aggregate, skip_on_error, **kwargs)
#     687         except Exception as exc:
#     688             if not skip_on_error:
# --> 689                 raise exc
#     690 self.datasets = self._create_derived_variables(datasets, skip_on_error)
#     691 return self.datasets
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/core.py:685, in esm_datastore.to_dataset_dict(self, xarray_open_kwargs, xarray_combine_by_coords_kwargs, preprocess, storage_options, progressbar, aggregate, skip_on_error, **kwargs)
#     683 for task in gen:
#     684     try:
# --> 685         key, ds = task.result()
#     686         datasets[key] = ds
#     687     except Exception as exc:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/core.py:836, in _load_source(key, source)
#     835 def _load_source(key, source):
# --> 836     return key, source.to_dask()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/source.py:300, in ESMDataSource.to_dask(self)
#     298 def to_dask(self):
#     299     """Return xarray object (which will have chunks)"""
# --> 300     self._load_metadata()
#     301     return self._ds
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake/source/base.py:84, in DataSourceBase._load_metadata(self)
#      82 """load metadata only if needed"""
#      83 if self._schema is None:
# ---> 84     self._schema = self._get_schema()
#      85     self.dtype = self._schema.dtype
#      86     self.shape = self._schema.shape
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/source.py:220, in ESMDataSource._get_schema(self)
#     218 def _get_schema(self) -> Schema:
#     219     if self._ds is None:
# --> 220         self._open_dataset()
#     221         metadata: dict[str, typing.Any] = {'dims': {}, 'data_vars': {}, 'coords': ()}
#     222         self._schema = Schema(
#     223             datashape=None,
#     224             dtype=None,
#    (...)
#     227             extra_metadata=metadata,
#     228         )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/intake_esm/source.py:292, in ESMDataSource._open_dataset(self)
#     289     self._ds.attrs[OPTIONS['dataset_key']] = self.key
#     291 except Exception as exc:
# --> 292     raise ESMDataSourceError(
#     293         f"""Failed to load dataset with key='{self.key}'
#     294          You can use `cat['{self.key}'].df` to inspect the assets/files for this key.
#     295          """
#     296     ) from exc
#
# ESMDataSourceError: Failed to load dataset with key='atm.ssp370.monthly.smbb'
#                  You can use `cat['atm.ssp370.monthly.smbb'].df` to inspect the assets/files for this key.
